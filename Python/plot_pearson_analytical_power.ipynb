# %%
from pearson_analytical import plot_power
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize=(18, 10), ncols=2, sharex=True, sharey=True)
plot_power(r=0.2, Nmax=1000, ax=ax[0]);
plot_power(r=0.4, Nmax=1000, ax=ax[1]);
