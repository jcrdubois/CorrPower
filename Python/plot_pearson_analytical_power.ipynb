# %%
from pearson_analytical import plot_power
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize=(18, 10), ncols=1, sharex=True, sharey=True)
plot_power(rs=[0.2, 0.4, 0.6], alphas=0.05, Nmax=30, ax=ax);
# plot_power(rs=0.4, Nmax=30, ax=ax[1]);
